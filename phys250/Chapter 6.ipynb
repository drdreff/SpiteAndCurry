# %%
import numpy as np 
def dsin(x:float): return np.sin(np.deg2rad(x))
def dcos(x:float): return np.cos(np.deg2rad(x))
# remember numpy does everything in radians!
g = 9.8 # Gravity
# Find the tension in each of the three cables supporting the traffic light if it weighs 170 N.
# T1 41deg, T2 63deg T_y1sin(41) + T_y2sin(63) = 170N, since F_netx=0 T_x1cos(41)=T_x2cos(63) 
# Find the relation between the two angles: T_x1cos(41)/cos(63) = 1.66239069
# T_y1 sin(41) + (1.662T_y1)sin(63)=170
T_y1 = 170 / (np.sin(np.deg2rad(41))+1.662*np.sin(np.deg2rad(63))) 
T_y2 = T_y1 * 1.66239069
print(f'T_y1 = {T_y1} T_y2 = {T_y2}') 

# A service elevator takes a load of garbage, mass 10.0 kg, from a floor of a skyscraper under 
# construction, down to ground level, accelerating downward at a rate of 1.2 m/s2. Find the 
# magnitude of the force the garbage exerts on the floor of the service elevator.
# F = mg - ma = m(g - a) = (10.0kg)(9.8 - 1.2)
F = 12 * (9.8-1.9)
print(f'F={F}')

# Atwood Machine 
# (m2 - m1)g = (m1 + m2)a
# a=((m2-m1)/(m1+m2))g
m1 = 1.8
m2 = 4.5 
a = g*((m2-m1)/(m1+m2))
print(f'a={a}')
T = m1*(g+a)
print(T)

'''
Two blocks are connected by a massless rope as shown below. The mass of the block on the 
table is 3.2 kg and the hanging mass is 0.8 kg. The table is frictionless, and the pulley 
is frictionless and massless. (a) Find the acceleration of the blocks. (b) Find the tension 
in the rope. (c) Find the speed with which the hanging mass hits the floor if it starts from 
rest and is initially located 1.2 m from the floor.

a = g*((m2)/(m1+m2))
T = g*((m1*m2)/(m1+m2)) 

v^2 = v0^2 + 2a(x - x0) for this:  
v = sqrt(0+2a(1.2 - 0))
'''
m1 = 3.2
m2 = 0.8
a= g*((m2)/(m1+m2))
T = g*((m1*m2)/(m1+m2)) 
v=np.sqrt(2*a*1.2)
print('Question 4:')
print(f'a={a}')
print(f'T={T}')
print(f'v={v}')

'''
A 1.8 kg block (mass 1) and a 3.2 kg block (mass 2) are connected by a light string as shown; 
the inclination of the ramp is 40°. Friction is negligible. What is (a) the acceleration of 
each block and (b) the tension in the string?

This is one where we want to decompose the components of g for m1
m2*g -T = m2 *a
T - m1 * g * sin(theta)=m1 * a
a = ((m2*g-m1*g*sin(theta))/(m1+m2)) 
T = (m1*g*sin(theta)) + (m1 * a) 
'''
print('Question 5:')
m1 = 1.8
m2 = 3.2
a = ((m2*g*dsin(40))/(m1+m2))
T = (m1*g*dsin(40)) + (m1 * a) 
print(f'a={a}')
print(f'T={T}')

'''
At a post office, a parcel that is a 20.0-kg box slides down a ramp inclined at 24.1° 
with the horizontal. The coefficient of kinetic friction between the box and plane is 0.0300.

Find the acceleration of the box: 
R = m1*g*cos(theta)
a = ((m * g * sin(theta)) - (mu * R))/m
Find the velocity of the box as it reaches the end of the plane, if the length of the 
plane is 1.6 m and box starts at rest.

'''
print('Question 6:')
m1 = 20
mu = 0.03 
theta = 24.1
R = m1 * g * dcos(theta)
d=1.6
a = ((m1 * g * dsin(theta)) - (mu * R))/m1
v=np.sqrt(2*a*d)
print(f'a = {a} v = {v}')

'''
Calculate the centripetal force on the end of a 115-m (radius) wind turbine blade that is 
rotating at 0.5 rev/s. Assume the mass is 6 kg.

velocity is: revs * 2 pi /s 

a_c = v^2/r 
F_c = ma_c

rev/s = (pi * r )s 
'''
print('Question 7:')
rev = 0.5
m1 = 6
r = 115
a = np.power((2 * np.pi * rev),2)*r
F= m1 * a 
print(f'F_c = {F}')
# LaTex:
# a_T = \frac{d|\overrightarrow{v}|}{dt}


# Ma = 1.4863
# Mb = 0.4962
Ma = 0.5
Mb = 1.5
100*(-1 * Mb)/(Ma+Mb)

print('rat',(-17.09)/(-30.76))
V_aix=10 #m/s

V_afx=((Ma-Mb)/(Ma+Mb))*V_aix
V_bfx=((Ma *2)/(Ma+Mb))*V_aix

print('va', V_afx)
print('vb', V_bfx)
# Out:
# T_y1 = 79.55405284245595 T_y2 = 132.24991679706682
# F=94.80000000000001
# a=4.2
# 25.2
# Question 4:
# a=1.9600000000000002
# T=6.272000000000002
# v=2.1688706738761536
# Question 5:
# a=4.031563887953975
# T=18.595588433187707
# Question 6:
# a = 3.7332652636310586 v = 3.456363528857951
# Question 7:
# F_c = 6810.027036751657
# rat 0.5555916775032509
# va -5.0
# vb 5.0

# %% [markdown]
# $ F_k = \mu \cdot F_N $
# $ F_N = F_{wy} = F_w \cdot cos(\theta)$
#
# Chapter 7: Work Formulas
#
# $ dW = \vec{F} \cdot d\vec{x} = |\vec{F}| | d\vec{x} | cos\theta $
#
# A toy cart is pulled a distance of 6.0 m in a straight line across the floor. The force pulling the cart has a magnitude of 28.5 N and is directed at 45° above the horizontal. What is the work done by this force?
#
# $ W = Fd cos\theta = (28.5N)(6m)cos(45^\circ) = 120.9155J$
#
# A sled plus passenger with total mass 65 kg is pulled 23 m across the snow ( μk=0.2 ) at a constant velocity by a force directed 25° above the horizontal.
#
# Calculate the work of the applied force: calculate the magnitude of the applied force, then the x
#
# $ W = F_T cos\theta d \text{Need to find } F_T = \frac{mg\mu_k}{cos\theta+\mu_k sin\theta} $
#
# calculate the work of friction: $W = F cos\theta d$
#
# calculate magnitude of friction: $ F = mg\left(\frac{1}{1+\mu_k tan\theta}\right)\mu_k$
#
#
# calculate total work
#
# How much work does the force $F(x)=\left( - \frac{2.0}{x} \right) N$ do on a particle as it moves from $x=2.0m$ to $x=5.0m$?
#
# $ W=\int_{x_i}^{x_f} F(x)dx = -2.0 ln\frac{8.0}{2.0} = -2.772588722$
#
# How much work is done against the gravitational force on a 3.5-kg briefcase when it is carried from the ground floor to the roof of the Empire State Building, a vertical climb of 380 m?
#
# $W = 3.5 kg \cdot 9.8 \frac{m}{s^2} \cdot 380m = 13034J$
#
# A bungee cord exerts a nonlinear elastic force of magnitude $F(x)=k_1 x + k_2 x^3 $, where x is the distance the cord is stretched,
# $k_1 = 190 \frac{N}{m}$  and
# $k_2 = -0.223 \frac{N}{m^3}$. How much work must be done on the cord to stretch it 16.7 m?
#
# $ W = \int_{0}^{x_f} F(x)dx = \frac{1}{2}k_1 x^2_f+\frac{1}{4}k_2 x^4_f$
#
# $W=\frac{1}{2}\left( 190\frac{N}{m}\right)\left(16.7m\right)^2+\frac{1}{4}\left( -0.223 \frac{N}{m}\right)\left( 16.7m\right)^4= 22.158.33551kJ$
#
#
# A 4-kg body has three times the kinetic energy of an 5-kg body. Calculate the ratio of the speeds of these bodies.
#
# An 8.0-g bullet has a speed of 680 m/s.
# $K = \frac{1}{2}mv^2 $
#
# $K = \frac{1}{2}0.008\cdot \left(680\frac{m}{s^2} \right) = 1849.6$
#
# Calculate the force needed to bring a 978-kg car to rest from a speed of 99 km/h in a distance of 120 m (a fairly typical distance for a non-panic stop).
# 99km/h = 27.5 m/s looking for $F=ma$
#
# $v_f^2 = v_0^2 + 2ax \text{ or } a = \frac{v_f^2 - v_i^2}{2x} $
#
# $ a = \frac{(2.75m^s)^2}{2 \cdot 120m} \cdot 978kg = 3081.71875N $
#
# A cyclist in a race must climb a 5° hill at a speed of 7 m/s. If the mass of the bike and the biker together is 61 kg, what must be the power output of the biker to achieve the goal?
#
# $ P = mgv\text{sin}5^\circ  P = 61 \cdot 9.8 \cdot 7 \cdot sin(5) = 364.7119211W$
#
# # Chapter 8
#
# ## Question 1
#
# The potential energy function for either one of the two atoms in a diatomic molecule is often approximated by
# $U(x)=\frac{a}{x^12}-\frac{b}{x^6} $where $x$  is the distance between the atoms.
#
# At what distance of separation does the potential energy have a local minimum (not at  $x=∞$ )? Express your answer algebraically.
#
# $\left(\frac{2a}{b}\right)^\frac{1}{6}$
#
# What is the force on an atom at this separation? $F(x-x_{min})= 0 N$
#
# ## Question 2
# A particle of mass 2-kg moves under the influence of the force $F(x)=\left(\frac{5}{\sqrt{x}}\right)N$. If its speed at $x=2.0 m$ is $v=5m/s$, what is its speed at
# $x=7.0m$?
#
# ## Question 3
#
# A boy throws a ball of mass 0.1 kg straight upward with an initial speed of 18 m/s When the ball returns to the boy, its speed is 17 m/s. How much work does air resistance do on the ball during its flight? (You can use work-energy theorem).
#
# $KE_i + PE_i - W_{nc} = KE_f + PE_f$
#
# $\frac{1}{2}mv^2_i-W_{nc}=\frac{1}{2}mv^2_f$
#
# $w_{nc}=\frac{1}{2}m\left(v^2_i - c^2_f\right)= \frac{1}{2}0.1\left(18^2 - 17^2\right) = 1.75J $
#
# ## Question 4
#
# Assume that the force of a bow on an arrow behaves like the spring force. In aiming the arrow, an archer pulls the bow back 53 cm and holds it in position with a force of 142 N. If the mass of the arrow is 45 g and the "spring" is massless, what is the speed of the arrow immediately after it leaves the bow?
#
# Hooke's Law: $\vec{F} = -k\vec{x}, a=kxm$
#
# $ v^2=2ax $
#
# $136 =-k50, k=-\frac{136}{50} $
#
# $ a = \frac{136}{.50} \cdot 53 \cdot 45 $
#
# $v = \sqrt{2ax}$
#
# ## Question 7
# The massless spring of a spring gun has a force constant $k=12.5 N/cm$. When the gun is aimed vertically, a 10-g projectile is shot to a height of 5.0 m above the end of the expanded spring. How much was the spring compressed initially?
#
# $\frac{1}{2}kx^2=mgh$
#
# ## Question 8
#
# A $6.5×10^5 kg$ subway train is brought to a stop from a speed of 0.500 m/s in 0.45 m by a large spring bumper at the end of its track. What is the spring constant $k$  of the spring?
#
# $k = \frac{mv^2}{x^2} $
#
# $\frac{\left(650000\right)\left(0.5\right)^2}{\left( 0.45\right)^2} = 802469$
#
# # Chapter 9
# ## Question 2
# What is the average momentum of a 63-kg sprinter who runs the 100-m dash in 10.45 s?
#
# $ \vec{p} = \frac{m_{kg}d_{m}}{t_{s}} = \frac{63 \cdot 100}{10.45} = 602.87 $
#
# ## Question 3
#
# Calculate the final velocity of a 101-kg rugby player who is initially running at 8 m/s but collides head-on with a padded goalpost and experiences a backward force of
# $ 1.76e10^4 N $ for $5.5e10^{-2}s$
#
# $ \vec{F_{av}} = \frac{m\Delta\vec{v}}{\Delta t} $
#
# for this head-on collision,
# $\Delta v = \frac{F_{av}\Delta t}{m}$ and $v_f = v_i + \frac{F_{av}\Delta t}{m}  $
#
# $v_f = 8\frac{m}{s} + \frac{\left(-1.76e10^4\right)\left(5.5e10^{-2}s\right)}{101kg} = -1.58 \frac{m}{s} $
#
# ## Question 4
# Water from a fire hose is directed horizontally against a wall at a rate of 45 kg/s and a speed of 43 m/s. Calculate the force exerted on the wall, assuming the water's horizontal momentum is reduced to zero.
#
# $F_N=m_{kg}a_{\frac{m}{s^2}}, a = \frac{\Delta v_\frac{m}{s}}{t_s} $
#
# $F = 45 \cdot \left(43 - 0 \right) = 1935N $
#
# ## Question 5
# The x-component of a force on a 48-g golf ball by a 7-iron versus time is plotted in the following figure.
# (0-50ms, 0-30N) (50-100ms 30-30N)
#
# Find the  x-component of the impulse during the intervals,
# [0, 50 ms]  [50 ms, 100 ms]
#
# Impulse momentum: $\vec{J} = \Delta\vec{p}$
#
#
#
# Find the change in the
# x -component of the momentum during the intervals,
#
# ## Question 6
# Train cars are coupled together by being bumped into one another. Suppose two loaded train cars are moving toward one another, the first having a mass of $2.05e10^5$ kg and a velocity of (0.30m/s)x, and the second having a mass of  $1.3e10^5$ kg and a velocity of -(0.12 m/s)x^ . What is their final velocity?
#
# Using conservation of momentum: $\vec{p_i}=\vec{p_f}$
#
# $ m_1\vec{v_{1i}}+m_2\vec{v_{2i}} = \left(m_1+m_2\right) \vec{v_f}$
#
# $ \vec{v_f} = \frac{m_1\vec{v_{1i}}+m_2\vec{v_{2i}}}{m_1+m_2}$
#
# $\vec{v_f} = \frac{\left(2.05e10^5kg\right)\left(0.3\frac{m}{s}\right)\hat{x}+\left(1.1e10^5kg\right)\left(-0.12\frac{m}{s}\right)\hat{x} }{\left(2.05 + 1.3 \right)e10^5kg}$
#
# $\vec{v_f} = .01370\frac{m}{s}$
#
# ## Question 7
# The figure below shows a bullet of mass 130 g traveling horizontally towards the east with speed 600 m/s, which strikes a block of mass 5 kg that is initially at rest on a frictionless table.
#
# part a: is the speed of the block/bullet combination immediately after the impact?
#
# The speed of the combination is: $\vec{v_f} = \frac{\left(0.130kg\right)\left(600\frac{m}{s}\right)\hat{x}+\left(5kg\right)\left(0\frac{m}{s}\right)\hat{x} }{\left(5.130\right)kg} = 15.2m/s$
#
# part b: What is the magnitude and direction of the impulse by the block on the bullet?
# The block exerts an impulse of $ \vec{J}=m\Delta\vec{v} ... \vec{J}=0.130kg\cdot\left(600 -15.2\right) = 76.024Ncs$ Westward
#
# part c: If it took 5 ms for the bullet to change the speed from 600 m/s to the final speed after impact, what is the average force between the block and the bullet during this time?  $ \vec{J} = \vec{F_{av}}\Delta t , \frac{\vec{J}}{\Delta t} =\vec{F_{av}}, \vec{F_{av}}= \frac{76.024}{0.005} = 15204.8N$
#
# Of the kinetic energy initially present in the bullet, what percentage still remains as kinetic energy of the block/bullet?
# $KE_i=\frac{1}{2}0.130kg \left(600 \frac{m}{s}\right)^2 = 46800J$
#
# $KE_f=\frac{1}{2}5.130kg \left(15.2 \frac{m}{s}\right)^2 = 1185.2352J$
#
# $ \frac{1185.2352}{46800} \cdot 100 = 2.53%$
#
# # Chapter 10
# ## Question 1
# A track star runs a 495-m race on a 495-m circular track in 46 s. What is his angular velocity assuming a constant speed?
#
# $\omega = \frac{2\pi \text{rad}}{46s} =  0.13659098493868665 $
#
# ## Question 2
#
# A particle moves 5 m along a circle of radius 1.2 m.
#
# Through what angle does it rotate? $\theta = \frac{5}{1.2} =  4.166666666666667 radians $
#
# If the particle makes this trip in 1.0 s at a constant speed, what is its angular velocity?
# $ \omega = \frac{\theta}{time} = 4.166666666666667$ radians/second
#
# What is the magnitude of its acceleration?
# $ a_c = \frac{v^2}{r} = \frac{5^2}{1.2} = 20.833333333333336 \frac{m}{s^2}$
#
# ## Question 3
#
# A flywheel slows from 450 to 400 rev/min while rotating through 26 revolutions.
# 7.5rps to 40/6rps
# What is the (constant) angular acceleration of the flywheel?
#
# $\alpha = \frac{\omega - \omega_0}{t} = \frac{2\pi\cdot \frac{400}{60} - 2\pi\cdot \frac{450}{60}}{t}$
#
# ## Question 4
# A vertical wheel with a diameter of 50 cm starts from rest and rotates with a constant angular acceleration of 5.5 rad/s^2 around a fixed axis through its center counterclockwise.
#
# Where is the point that is initially at the bottom of the wheel at
# t=12s? Express your answer as an angle in radians between 0 and
# 2π , relative to the positive
# x  axis.
#
# $ \theta_f = \theta_0 +\omega_0t+\frac{1}{2}\alpha t^2 = 4.87 radian$
#
# What is the point's tangential acceleration at this instant?
#
# $ a_t = r \alpha = 0.25m \cdot 5.5\frac{rad}{s^2} = 1.375 \frac{m}{s^2}$
#
# ## Question 5
#
# Calculate the rotational kinetic energy of a 12-kg motorcycle wheel if its angular velocity is 105 rad/s and its inner radius is 0.280 m and outer radius 0.330 m.
#
# $ K = \frac{1}{2}I\omega^2 $
#
# $ I = \frac{M}{2}(R^2_1 + R^2_2) $
#
# $ K = \frac{1}{2}\left(\frac{M}{2}\left(R^2_1 + R^2_2\right)\right)\omega^2$
#
# $ K = \frac{1}{2}\left(\frac{12}{2}\left(0.28^2 + 0.33^2\right)\right)\cdot 105^2 = 6194.947500000001 J$
#
# ## Question 6
# Two flywheels of negligible mass and different radii are bonded together and rotate about a common axis. The smaller flywheel of radius 27 cm ($r_1$) has a cord that has a pulling force ($F_1$) of 50 N on it. What pulling force ($F_2$) needs to be applied to the cord connecting the larger flywheel of radius 50 cm ($r_2$) such that the combination does not rotate?
#
# $ |\vec{\tau}| = \vec{r}\cdot\vec{F}$
#
# $ F_2 = \frac{r_1 \cdot F_1}{r_2} = \frac{0.27m \cdot 50N}{0.33m} = 27N$
#
# ## Question 7
#
# A flywheel  $\left(I = 43kg m^2\right)$  starting from rest acquires an angular velocity of 166 rad/s while subject to a constant torque from a motor for 5 s.
#
# What is the angular acceleration of the flywheel? $\alpha = \frac{\Delta\omega}{\Delta t} = \frac{166 - 0}{5-0} $
#
# What is magnitude of the torque? $ \tau = I\alpha = 33.2 \cdot 43 = 1427.6 $

# %%
# inelastic collision calculator for velocity:
m_1 = 67
m_2 = 0.003 
v_1 = 13
v_2 = -2

v_f = ((m_1*v_1) + (m_2*v_2))/(m_1+m_2)
v_f
v_1 - v_f

# ch 10 Q 1
print((2 * np.pi )/46)

print(5/1.2)
theta = 5/1.2
omega = theta /  1
print(25/1.2)

# Chapter 10 Question 5 
KE = (((6*(np.square(0.28)+ np.square(0.33)))/2)*np.square(105))

print (f'K={KE}')
# Out:
# 0.13659098493868665
# 4.166666666666667
# 20.833333333333336
# K=6194.947500000001

# %% [markdown]
# # Chapter 11
#
# ## Question 1
# A bowling ball rolls up a ramp 0.9 m high without slipping. It has an initial velocity of its center of mass of 4 m/s.
#
# What is its velocity at the top of the ramp?
#
# $ KE_R = \frac{1}{2}I\omega^2 $
#
# $ KE_{ri} + KE_{mi} + PE_i = KE_{rf} + KE_{mf} + PE_f$
#
# $ \frac{1}{2}I\omega_i^2 + \frac{1}{2}mV_i^2 = \frac{1}{2}I\omega_f^2 + \frac{1}{2}mV_f^2 + mgh_f $
#
# $ \frac{1}{3}r^2\omega_i^2 + \frac{1}{2}V_i^2 = \frac{1}{3}r^2\omega_f^2 + \frac{1}{2}V_f^2 + gh_f $
#
# $ V_T =r\omega $ therefore: $ V_T^2 = \left(rw\right)^2$
#
# $ \frac{2}{6}V_{Ti}^2 + \frac{3}{6}V_{Ti}^2 = \frac{2}{6}V_{Tf}^2 + \frac{3}{6}V_{Tf}^2 + gh_f $
#
#
#
# If the ramp is 1.6 m high does it make it to the top?
#
# Solving for "Max height"
#
# $ \frac{1}{2}I\omega_i^2 + \frac{1}{2}mV^2=mgh_f $
#
# exapnding $I$ for a sphere:
#
# $ \frac{1}{2}\left(\frac{2}{3}mr^2\right)\omega_i^2 + \frac{1}{2}mV^2=mgh_f $
#
# $ \frac{1}{3}r^2\omega_i^2+\frac{1}{2}V_i^2 = gh_f$
#
# $ V_T =r\omega $ therefore: $ V_T^2 = \left(rw\right)^2$
#
# $  \frac{1}{3} V_T^2 +\frac{1}{2}V_i^2 = gh_f$
#
#
# No: $  \frac{\frac{1}{3}  V_T^2 +\frac{1}{2}V_i^2}{g} = h_f = 1.3591m$
#
# ## Question 2
# A satellite is spinning at 6.0 rev/s. The satellite consists of a main body in the shape of a sphere of radius 2.0 m and mass 10450 kg, and two antennas projecting out from the center of mass of the main body that can be approximated with rods of length 3.0 m each and mass 10 kg. The antennas lie in the plane of rotation. What is the angular momentum of the satellite?
#
# $L = I_{sat}\omega $ where:
#
# $ I_{sat} = \frac{2}{5}\left(10450kg\right)\left(2.0m\right)^2+2\frac{1}{3}\left(10kg\right)\left(3.0m\right)^2$
#
# $ L = \left(16720kg\cdot m^2\right) \cdot \left( 2\pi\left(6.0\right)\frac{\text{rad}}{s}\right) = 630329.15 \frac{kg m^2}{s}$
#
# ## Question 3
#
# ## Question 4
# A playground merry-go-round has a mass of 140 kg and a radius of 1.8 m and it is rotating with an angular velocity of 0.45 rev/s. What is its angular velocity after a 22-kg child gets onto it by grabbing its outer edge? The child is initially at rest.
#
# $0.45 \cdot 2 \pi $
#
# $ \frac{140kg \cdot (1.8m)^2}{2*(0.45\cdot 2\pi)} / \frac{140kg \cdot (1.8m)^2}{2+22 \cdot (1.8m)^2}$

# %% [markdown]
# # CH 11 Q1 second part first
# V_t=4
# h_f = 0.9
#
# print( (np.square(V_t)/3 + np.square(V_t)/2 )/9.81)
#
# print( np.sqrt(np.square(V_t)-((9.81*h_f)/(5/6))))
#
# print( (((140 * np.square(1.8))/(2*2*0.45*np.pi))/((140 * np.square(1.8)/2+22*np.square(1.8)))
#        *2*np.pi))

# %% [markdown]
# # Chapter 12 & 13 Problems
# ## Question 1
# When tightening a bolt, you push perpendicularly on a wrench with a force of 145 N at a distance of 0.15 m from the center of the bolt. How much torque are you exerting relative to the center of the bolt?
#
# $\tau = Fd $
#
# $ \tau=145N \cdot 0.15m = 21.75 Nm $
#
# ## Question 2
# Two children push on opposite sides of a door during play. Both push horizontally and perpendicular to the door. One child pushes with a force of 17 N at a distance of 0.6 m from the hinges, and the second child pushes at a distance of 0.45 m. What force must the second child exert to keep the door from moving? Assume friction is negligible.
#
# Using the equilibrium condition for torques, $F_1 d_1 = F_2 d_2 $
#
# $ F_2 = F_1 \frac{d_1}{d_2} = 17N \frac{0.6m}{0.45m} = 22\frac{2}{3}Nm $
#
# ## Question 3
# A uniform plank rests on a level surface with 4.2m on a table, and 1.8m overhang. The plank has a mass of 41 kg ($M_p$) and is 6.0 m long. How much mass ($M_a$) can be placed at its right end before it tips?
#
# $ M_a(1.8m) = M_p(4.2m -3m) $
#
# $ M_a = 41kg \cdot \frac{1.2m}{1.8m} = 27\frac{1}{3}kg $
#
# ## Question 4
# A uniform 50-kg scaffold of length 7.0 m is supported by two light cables, as shown below. A 62-kg painter stands 1.0 m from the left end of the scaffold, and his paint bucket is 1.5 m from the right end. If the tension in the left cable is twice that in the right cable, find the tensions in the cables and the mass of the bucket.
#
# _remember the fulcrum is at the cable, r is from the cable to the center of mass for the scaffold_
#
#
# $ T_{left} = \left( m_{scaff}\cdot g \cdot r_{left cable} \right) + \left( m_{painter} \cdot g \cdot r_{left cable}\right) +
# \left( m_{bucket} \cdot g \cdot r_{left cable}\right) $
#
# $ 7m \cdot T_r = (50kg(9.8)\cdot 3.5m) + (62kg(9.8)\cdot 1m) + M_b(9.8)(5.5) $
#
# $ 7m \cdot T_r = 1715 + 607.6 + M_b(53.9) $
#
# $ 5.5m \cdot 2 T_r =  \left( m_{painter} \cdot g \cdot r_{bucket}\right) + 1.5 \cdot T_r$
#
# $ 11m T = ( 62 \cdot\9.8\cdot 4.5 ) + (50 \cdot 9.8 \cdot 2m) + 1.5m T$
#
# $ 9.5 T_r = 2734.2 + 980 $
#
# $ T_r = 390.9684N $
#
# This value gets plugged in to the first formula to get $M_b$
# $ m_{bucket} = X kg $
#
# $ T_{left} = XN$
#
# $ T_{right} = 390.97 N$
#
# ## Question 5
# Estimate the gravitational force between two sumo wrestlers, with masses 222 kg and 212 kg, when they are embraced and their centers are 1.1 m apart. Use $G=6.774x10^-11 Nm^2/kg^2$
#
# $ \vec{F_{12}}=G\frac{m_1\cdot m_2}{r^2}\hat{r_{12}} $
#
# $ F = \frac{222 \cdot 212 }{1.1^2}  = 2.595910214876033 \cdot 10^{-6} $
#
# ## Question 6
# Calculate the gravitational force exerted on a 4.37-kg baby by a 100-kg father 0.200 m away at birth (he is assisting, so he is close to the child).
#
# Calculate the force on the baby due to Jupiter ($1.9 x 10^{27}kg$)  if it is at its closest distance to Earth, some $6.29x10^{11}m$ away.
#
# $F_G = G\frac{m_1 m_2}{r^2}\hat{r_{12}}$
#
# ## Question 7
# On a planet whose radius is $2.3×10^7m$ , the acceleration due to gravity is $22 \frac{m}{s^2}$. What is the mass of the planet ($M_p$)? Express your answer in scientific notation in the provided spaces below.
#
# $ g = G\frac{M_p}{r^2} $
#
# $ M_p = \frac{gR_p^2}{G} = \frac{22\frac{m}{s^2}(2.3×10^7m)^2}{6.674x10^{-11}\frac{Nm^2}{kg^2}}$
#
# $ M_p = 1.7437818399760266\cdot 10^{26}kg$
# Lab Formula: $ m_2 = \frac{4\pi^2}{G\cdot C} \rho \sigma$

# %%
# Question 4 

T_l = (50 * 9.8 * 3.5 ) + (58 * 9.8 * 6)

# Question 5
G = 6.674 * pow(10, -11)

print('Q5: ', G * ((222*212)/pow(1.1,2)))

# Question 6 
print('Q6a: ',G * ((4.37*100)/pow(0.2,2)))
print('Q6b: ', G * ((4.37*1.9*pow(10,27))/pow(6.29 * pow(10,11),2)))

# Question 7 

print('Q7: ',22 * pow(2.3*pow(10,7),2) /G)
# Out:
# Q5:  2.595910214876033e-06
# Q6a:  7.291344999999998e-07
# Q6b:  1.4006187932999861e-06
# Q7:  1.7437818399760266e+26

# %% [markdown]
# # Chapter 14
# ## Question 1
#
# Suppose you have a coffee mug with a circular cross-section and vertical sides (uniform radius). What is its inside radius if it holds 405 g of coffee when filled to a depth of 7.50 cm? Assume coffee has the same density as water.
#
# $ V= \pi r^2h $
#
# $ r = \sqrt{\frac{V}{\pi h}} \text{ ergo: } 4.146 = \sqrt{\frac{405}{\pi\cdot 7.5}} $
#
# ## Question 2
# A trash compactor can compress its contents to 0.39 times their original volume. Neglecting the mass of air expelled, by what factor is the density of the rubbish increased?
#
# factor: $ \frac{1}{comp} ... \frac{1}{0.39}= 2.56 $
#
# ## Question 3
# The tip of a nail exerts tremendous pressure when hit by a hammer because it exerts a large force over a small area. What force must be exerted on a nail with a circular tip of 1.00-mm diameter to create a pressure of $6×10^9 \frac{N}{m^2} ? (This high pressure is possible because the hammer striking the nail is brought to rest in such a short distance.)
#
# $ p = \frac{F}{A} $
#
# $ 6000000000 = \frac{F}{\pi0.0005^2} $
#
# ## Question 4
# The greatest ocean depths on Earth are found in the Marianas Trench near the Philippines. Calculate the pressure due to the ocean at the bottom of this trench, given its depth is 10.9 km and assuming the density of seawater (ρ= 1022 kg/m3) is constant all the way down.
#
# $ p = p_0 +\rho h g $
#
# $ P = 1022 \cdot 10900 \cdot 9.81 = 109281.438 kPa$
#
# ## Question 5
# Assuming bicycle tires are perfectly flexible and support the weight of a bicycle and rider by pressure alone, calculate the total area of the tires in contact with the ground if a bicycle and rider have a total mass of 62 kg, and the gauge pressure in the tires is $3×10^5$ Pa .
#
# $P = \frac{F}{A} , 300,000 = \frac{62g}{a} , 20.274 cm^2= \frac{62kg \cdot 9.81}{300000}$
#
# ## Question 6
# What force must be exerted on the master cylinder of a hydraulic lift to support the weight of a 2200-kg car (a large car) resting on a second cylinder? The master cylinder has a 5.5-cm diameter and the second cylinder has a 24.0-cm diameter.
#
# $\frac{F}{A} = \frac{F}{A} ... \frac{F}{\pi 0.0275^2} = \frac{2200kg \cdot g }{ \pi 0.12^2} = 1132.2743N $
#
# ## Question 7
#
# ## Question 8
# What is the fluid speed in a fire hose with a 11-cm diameter carrying 84 L of water per second?
#
# $ Vel = \frac{Vol}{\pi r^2} $
#
# $ V = \frac{84}{\pi 5.5^2} = 0.8839 $
#
# $ \left(\frac{PredictedProduction}{ProductiveTime}\right)\cdot\left(\frac{Curtailed \%}{CurtailedTime}\right) $

# %% [markdown]
# # Chapter 15
# ## Question 1
# Find the frequency of a tuning fork that takes
# $ 2.4E10^{-3}s$ to complete one oscillation.
#
# $f =\frac{1}{period} = \frac{1}{2.4E10^{-3}s} = 416.667Hz $
# ## Question 2
# A 0.6-kg mass suspended from a spring oscillates with a period of 1.00 s. How much mass must be added to the object to change the period to 2 s?
#
# $ T_1 = 2\pi\sqrt{\frac{m_1}{k}} \\
# \text{Solve for }k : k = 4\pi^2\frac{m_1}{T^2_1} \\
# \text{For the new period:} m_2 = \frac{T^2_2k}{4pi^2} = m_1\frac{T^2_2}{T^2_1} \\
# \text{The added mass } M \text{ is:} \\
# M=m_2-m_1 = m_1\left(\frac{T^2_2}{T^2_1}-1\right) = \left( 0.6kg \right) \left(\left(\frac{2s}{1s}\right)^2-1\right) \\
# M= 1.7999999999999998kg $
#
# ## Question 3
# A novelty clock has a 0.0100-kg-mass object bouncing on a spring that has a force constant of 1.05 N/m. What is the maximum velocity of the object if the object bounces 3.00 cm above and below its equilibrium position?
# $v_\text{max} = \sqrt{\frac{k}{m}}\cdot A m/s\\
# v_\text{max} =  \sqrt{\frac{1.05N}{0.01kg}}\cdot 0.03m \\
# v_\text{max} =  0.3074085m/s
# $
# How many joules of kinetic energy does the object have at its maximum velocity?
# $KE_\text{max} = \frac{1}{2}mv^2 = \frac{1}{2}0.01kg \cdot 0.3074085^2 = 4.725E10^{-4}J$
# ## Question 4
# What is the length of a pendulum that has a period of 0.85s?
# $ T= 2\pi\sqrt{\frac{L}{g}} \\
# \text{Solve for }L: L=g\left(\frac{T}{2\pi}\right)^2 \\
# L= 9.81\left(\frac{0.85}{2\pi}\right)^2 = 0.1795m $
# ## Question 5
# Suppose a diving board with no one on it bounces up and down in a SHM with a frequency of 3.75 Hz. The board has an effective mass of 8 kg. What is the frequency of the SHM of a 75.0-kg diver on the board?
#
# $ f= \frac{1}{2\pi}\sqrt{\frac{k}{m}} \\
# \text{First solve for }k: k = \frac{\left(2\pi f\right)^2}{m} \\
# f_2 = \frac{1}{2\pi}\sqrt{\frac{2\pi f_1 m_1}{m_2} }\\
# f_2 = \frac{1}{2\pi}\sqrt{\frac{2\pi 3.75Hz \cdot 8kg}{75kg + 8kg} }\\
# f_2 =1.1642Hz
# $
# ## Question 6
# A mass is placed on a frictionless, horizontal table. A spring $( k=115 N/m )$, which can be stretched or compressed, is placed on the table. A 2-kg mass is anchored to the wall. The equilibrium position is marked at zero. A student moves the mass out to  $x=7.0 cm$  and releases it from rest. The mass oscillates in simple harmonic motion. Find the position, velocity, and acceleration of the mass at time $t=3.00 s$.
#
# $x(t=3.0s) = A\text{cos}(\omega t)\\
# \omega=\sqrt{\frac{k}{m}} \\
# x(t=3.0s) = 7cm \text{cos}(\sqrt{\frac{145N/m}{4.5kg}}\cdot 3.0s)\\
# x(t=3.0s) = -1.727576 cm \\
# v_{\text{max}} = A\omega = 7\sqrt{\frac{145N/m}{4.5kg}} \\
# v(t=3.0s) = -v_{\text{max}}\text{sin}(\omega t ) = 38.5061166 cm/s\\
# a_{\text{max}}=A\omega^2 = 7 \cdot \frac{145N/m}{4.5kg} \\
# a(t=3.0s) = -a_{\text{max}}\text{cos}(\omega t) = 55.6663497 cm/s^2
# $
#
# # Chapter 16
# ## Question 1
# Storms in the South Pacific can create waves that travel all the way to the California coast, 11850 km away. How long does it take them to travel this distance if they travel at 11 m/s?
#
# $\frac{11850km}{11m/s} = \frac{1,077,272.727s}{3600s} = \frac{299.2424 hours}{24}= 12.4684 days $
#
# ## Question 2
# How many times per minute does a boat bob up and down on ocean waves that have a wavelength of 30 m and a propagation speed of 6 m/s?
#
# $\frac{30m}{6m/s} = 5 \text{seconds per wave, } = 12 \text{ bobs/minute } $
#
# ## Question 3
# Scouts at a camp shake the rope bridge they have just crossed and observe the wave crests to be 9.25 m apart. If they shake the bridge twice per second, what is the propagation speed of the waves?
#
# $ 2 \cdot 9.25 = 18.5 m/s $
#
# ## Question 4
# A wave is modeled by the wave function $y(x,t) = (0.26m)\text{sin}\left[ \frac{2\pi}{3.15m}\left(x-\left(14m/s\right)t\right)\right] $ What are the amplitude (
# $A$), wavelength ( $\lambda$), wave speed ($v$), period ($P$), frequency ( $f$ ), and wave number ( $k$ ) of the wave?
#
# $y(x,t) = (0.26m)\text{sin}\left[ \frac{2\pi}{3.15m}\left(x-\left(14m/s\right)t\right)\right] \\
# y(x,t) = A\text{sin}\left[ \frac{2\pi}{\lambda}\left(x-vt\right)\right] \\
# k=\frac{2\pi}{\lambda} =1.994662m^{-1}\\
# P=\frac{\lambda}{v} = 0.225s \\
# f=\frac{v}{\lambda} = 4.444 Hz
# $
# ## Question 5
#
# A piano wire has a linear mass density of μ=4.85E-3kg/m. Under what tension must the string be kept to produce waves with a wave speed of 452 m/s?
#
# $ v=\sqrt{\frac{T}{\mu}} \\
# T = v^2 \cdot\mu \\
# T = (452)^2\cdot 0.00485kg/m = 990.874N
# $

# %%
# q14.3
print( 6e9 * np.pi * np.square(0.0005))
# q14.4 
print ( (1022 * 10900 * 9.81)/1000 ) 
# q14.5 
print(((62 * 9.81)/300000)*10000) 
# q14.6
print((2200 * g * np.pi * np.square(0.0275))/(np.pi * np.square(0.12)))
# q14.8 
print(84 /(np.pi * np.square(5.5))) 
print(1/(84 /(np.pi * np.square(5.5)))) 
# q15.2
print(0.6*3)
# q15.3a
print(np.sqrt(1.05/0.01)*0.03)
# q15.3b
print(np.square(np.sqrt(1.05/0.01)*0.03)*.01*.5)
# q15.4 
print(9.81*np.square(0.85/(2*np.pi)))
# q15.5
print((1/(2*np.pi))*np.sqrt(( np.square(3.75 * np.pi * 2)*8 )/83)
)
# q15.6a
print(7 * np.cos(np.sqrt(145/4.5)*3 )
)
# q15.6b
v_max = 7 * np.sqrt(145/4.5)
print('v(t=3.0s) ',
-1*v_max * np.sin(np.sqrt(145/4.5)*3))
# q15.6c
a_max = 7*145/4.5 
print('a(t=3.0s) ',
        -1*a_max*np.cos(np.sqrt(145/4.5)*3)
     )
# Out:
# 4712.388980384689
# 109281.438
# 20.274
# 1132.2743055555554
# 0.8839018327087079
# 1.131347354417753
# 1.7999999999999998
# 0.3074085229787879
# 0.0004724999999999999
# 0.17953417158284712
# 1.164225788559499
# -1.7275763702022615
# v(t=3.0s)  38.506116637756314
# a(t=3.0s)  55.66634970651731
